# %%
import nltk
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# ...

# %%
import requests
import urllib.request
#response =  urllib.request.urlopen('https://en.wikipedia.org/wiki/SpaceX')
response =  urllib.request.urlopen('https://aws.amazon.com/free/webapps/?trk=88893ae2-92d7-4e54-886e-0a0b3c8b0967&sc_channel=ps&s_kwcid=AL!4422!3!531231487640!p!!g!!wordpress%20website&ef_id=Cj0KCQjwwfiaBhC7ARIsAGvcPe5PCAAfNLFdg2jC-93_-tVi7qAgZOdNFxqqubld6_eE9tcAt4Ux1gwaAnv-EALw_wcB:G:s&s_kwcid=AL!4422!3!531231487640!p!!g!!wordpress%20website')
html = response.read()
print(html)
# Out:
# b'<!doctype html>\n<html class="no-js aws-lng-en_US aws-with-target" lang="en-US" data-static-assets="https://a0.awsstatic.com" data-js-version="1.0.485" data-css-version="1.0.445">\n <head> \n  <meta http-equiv="Content-Security-Policy" content="default-src \'self\' data: https://a0.awsstatic.com; connect-src \'self\' https://112-tzm-766.mktoresp.com https://112-tzm-766.mktoutil.com https://a0.awsstatic.com https://a0.p.awsstatic.com https://a1.awsstatic.com https://amazonwebservices.d2.sc.omtrdc.net https://amazonwebservicesinc.tt.omtrdc.net https://api.regional-table.region-services.aws.a2z.com https://api.us-west-2.prod.pricing.aws.a2z.com https://auth.aws.amazon.com https://aws.amazon.com https://aws.demdex.net https://b0.p.awsstatic.com https://c0.b0.p.awsstatic.com https://calculator.aws https://chatbot-api.us-east-1.prod.mrc-sunrise.marketing.aws.dev https://cm.everesttech.net https://csml-plc-prod.us-west-2.api.aws/plc/csml/logging https://d0.awsstatic.com https://d1.awsstat
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html,'html.parser')
text = soup.get_text(strip = True)
print(text)
# Out:
# Build Free Websites and WebappsSkip to Main ContentClick here to return to Amazon Web Services homepageContact UsSupportEnglishMy AccountSign InCreate an AWS AccountProductsSolutionsPricingDocumentationLearnPartner NetworkAWS MarketplaceCustomer EnablementEventsExplore MoreCloseعربيBahasa IndonesiaDeutschEnglishEspañolFrançaisItalianoPortuguêsTiếng ViệtTürkçeΡусскийไทย日本語한국어中文 (简体)中文 (繁體)CloseAWS Management ConsoleAccount SettingsBilling & Cost ManagementSecurity CredentialsAWS Personal Health DashboardCloseSupport CenterKnowledge CenterAWS Support OverviewAWS re:PostClick here to return to Amazon Web Services homepageGet Started for FreeContact UsProductsSolutionsPricingIntroduction to AWSGetting StartedDocumentationTraining and CertificationDeveloper CenterCustomer SuccessPartner NetworkAWS MarketplaceSupportAWS re:PostLog into ConsoleDownload the Mobile AppBuild Free Websitesand Web Apps on AWSFree offers and services you need to build, deploy, host, and manage websites and web ap
# ...

# %%
tokens = [t for t in text.split()]
print(tokens)
# Out:
# ['Build', 'Free', 'Websites', 'and', 'WebappsSkip', 'to', 'Main', 'ContentClick', 'here', 'to', 'return', 'to', 'Amazon', 'Web', 'Services', 'homepageContact', 'UsSupportEnglishMy', 'AccountSign', 'InCreate', 'an', 'AWS', 'AccountProductsSolutionsPricingDocumentationLearnPartner', 'NetworkAWS', 'MarketplaceCustomer', 'EnablementEventsExplore', 'MoreCloseعربيBahasa', 'IndonesiaDeutschEnglishEspañolFrançaisItalianoPortuguêsTiếng', 'ViệtTürkçeΡусскийไทย日本語한국어中文', '(简体)中文', '(繁體)CloseAWS', 'Management', 'ConsoleAccount', 'SettingsBilling', '&', 'Cost', 'ManagementSecurity', 'CredentialsAWS', 'Personal', 'Health', 'DashboardCloseSupport', 'CenterKnowledge', 'CenterAWS', 'Support', 'OverviewAWS', 're:PostClick', 'here', 'to', 'return', 'to', 'Amazon', 'Web', 'Services', 'homepageGet', 'Started', 'for', 'FreeContact', 'UsProductsSolutionsPricingIntroduction', 'to', 'AWSGetting', 'StartedDocumentationTraining', 'and', 'CertificationDeveloper', 'CenterCustomer', 'SuccessPartner', 'NetworkAWS'
# ...

# %%
from nltk.corpus import stopwords
sr= stopwords.words('english')
clean_tokens = tokens[:]
for token in tokens:
    if token in stopwords.words('english'):
        
        clean_tokens.remove(token)

# %%
freq = nltk.FreqDist(clean_tokens)
for key,val in freq.items():
    print(str(key) + ':' + str(val))
# Out:
# Build:1
# Free:14
# Websites:2
# WebappsSkip:1
# Main:1
# ContentClick:1
# return:2
# Amazon:15
# Web:15
# Services:5
# homepageContact:1
# UsSupportEnglishMy:1
# AccountSign:3
# InCreate:1
# AWS:37
# AccountProductsSolutionsPricingDocumentationLearnPartner:1
# NetworkAWS:2
# MarketplaceCustomer:1
# EnablementEventsExplore:1
# MoreCloseعربيBahasa:1
# IndonesiaDeutschEnglishEspañolFrançaisItalianoPortuguêsTiếng:2
# ViệtTürkçeΡусскийไทย日本語한국어中文:2
# (简体)中文:2
# (繁體)CloseAWS:1
# Management:1
# ConsoleAccount:1
# SettingsBilling:1
# &:8
# Cost:1
# ManagementSecurity:1
# CredentialsAWS:1
# Personal:1
# Health:1
# DashboardCloseSupport:1
# CenterKnowledge:1
# CenterAWS:2
# Support:4
# OverviewAWS:1
# re:PostClick:1
# homepageGet:1
# Started:1
# FreeContact:1
# UsProductsSolutionsPricingIntroduction:1
# AWSGetting:2
# StartedDocumentationTraining:1
# CertificationDeveloper:1
# CenterCustomer:1
# SuccessPartner:1
# MarketplaceSupportAWS:1
# re:PostLog:1
# ConsoleDownload:1
# Mobile:2
# ...

# %%
freq.plot(20, cumulative=False)
# Out:
# <AxesSubplot: xlabel='Samples', ylabel='Counts'>
